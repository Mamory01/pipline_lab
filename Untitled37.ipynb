# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/models')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="r11hCW54EVmh3s4kueFo")
project = rf.workspace("yugo-lwrjm").project("tomato-ripeness-ukz1w")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 114.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.7 MB/s eta 0:00:00
# ...

# %%
# !yolo task = detect mode = train model=yolo26n.pt imgsz=640 data=/content/drive/MyDrive/models/Tomato-Ripeness-1/data.yaml epochs=30 batch=64 name=yolo26_tomato
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo task = detect mode = val model=/content/drive/MyDrive/models/runs/detect/yolo26_tomato/weights/best.pt name=yolo26_tomato_eval data=/content/drive/MyDrive/models/Tomato-Ripeness-1/data.yaml imgsz=640
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 5.6±10.5 ms, read: 18.2±12.8 MB/s, size: 59.3 KB)
# val: Scanning /content/drive/MyDrive/models/Tomato-Ripeness-1/valid/labels.cache... 121 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 121/121 16.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.8it/s 4.3s
#                    all        121       1167      0.706      0.761       0.79      0.711
#                 Matang         99        309      0.658      0.838      0.825      0.746
#                 Mentah        115        670      0.803      0.784      0.848      0.736
#        Setengah Matang         92        188      0.658       0.66      0.698       0.65
# Speed: 4.9ms preprocess, 8.0ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/models/runs/detect/yolo26_tomato/weights/best.pt source=/content/drive/MyDrive/models/Tomato-Ripeness-1/test/images imgsz=1280 name=yolo26_inference show_labels=True
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
#
# image 1/120 /content/drive/MyDrive/models/Tomato-Ripeness-1/test/images/IMG_20191215_111334_jpg.rf.ee1c77ef4905bfbe27035e21e7bba7c5.jpg: 1280x1280 6 Mentahs, 22.8ms
# image 2/120 /content/drive/MyDrive/models/Tomato-Ripeness-1/test/images/IMG_20191215_111338_jpg.rf.7b7eb4b0bd3574e35e81c3c60c1f5d0a.jpg: 1280x1280 2 Setengah Matangs, 37.5ms
# image 3/120 /content/drive/MyDrive/models/Tomato-Ripeness-1/test/images/IMG_20191215_111342_jpg.rf.fd6ea67adc33c50612dbdde29199696b.jpg: 1280x1280 5 Mentahs, 22.8ms
# image 4/120 /content/drive/MyDrive/models/Tomato-Ripeness-1/test/images/IMG_20191215_111355_jpg.rf.c6f590ec00d9d6c86a14f66d0d056577.jpg: 1280x1280 1 Matang, 2 Mentahs, 22.7ms
# ...
